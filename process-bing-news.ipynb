# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 40, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 998bedae-e7af-4da8-b117-5cd7046b7af1)

# %%
df =df.select("value")
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 41, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 42, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5c57f2b1-d5ae-4572-a562-2967ce92ec6d)

# %%
from pyspark.sql.functions import explode

df_explode = df.select(explode(df["value"]).alias("json_object"))
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 43, Finished, Available, Finished)

# %%
display(df_explode)
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 44, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 08fd5da6-10b3-46b7-9968-5f7451a6fc06)

# %%
json_list = df_explode.toJSON().collect()
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 45, Finished, Available, Finished)

# %%
print(json_list[0])
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 46, Finished, Available, Finished)
# {"json_object":{"about":[{"name":"Talanoa Hufanga","readLink":"https://api.bing.microsoft.com/api/v7/entities/142f965f-39cb-77db-2ec2-1475bd24dbb8"},{"name":"San Francisco 49ers","readLink":"https://api.bing.microsoft.com/api/v7/entities/0cd5038c-c2de-59f4-5e35-e580b51db5e0"},{"name":"Los Angeles Rams","readLink":"https://api.bing.microsoft.com/api/v7/entities/7cbf542f-6a08-45e0-af5f-60fe01d243c5"},{"name":"Kyle Shanahan","readLink":"https://api.bing.microsoft.com/api/v7/entities/e33e6585-227f-a485-2e39-50506464d59f"}],"datePublished":"2024-09-21T19:56:00.0000000Z","description":"El profundo Talanoa Hufanga ha estado entrenando con el resto del equipo las últimas dos semanas de manera limitada y se ha perdido los primeros dos juegos de la temporada. Hufanga logro recuperarse d","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.VP5KaqJje5S1YffDIp5zUi&pid=News","height":420,"width":630}},"name":"Talanoa Hufanga Logra Entrenar Sin Limitaciones","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.k6O3sRggnv9dZCaM2w5RLw&pid=news"}},"name":"Big News Network.com"}],"url":"https://www.bignewsnetwork.com/news/274621218/talanoa-hufanga-logra-entrenar-sin-limitaciones"}}

# %%
import json

news_json = json.loads(json_list[0])
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 47, Finished, Available, Finished)

# %%
print(news_json)
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 48, Finished, Available, Finished)
# {'json_object': {'about': [{'name': 'Talanoa Hufanga', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/142f965f-39cb-77db-2ec2-1475bd24dbb8'}, {'name': 'San Francisco 49ers', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/0cd5038c-c2de-59f4-5e35-e580b51db5e0'}, {'name': 'Los Angeles Rams', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/7cbf542f-6a08-45e0-af5f-60fe01d243c5'}, {'name': 'Kyle Shanahan', 'readLink': 'https://api.bing.microsoft.com/api/v7/entities/e33e6585-227f-a485-2e39-50506464d59f'}], 'datePublished': '2024-09-21T19:56:00.0000000Z', 'description': 'El profundo Talanoa Hufanga ha estado entrenando con el resto del equipo las últimas dos semanas de manera limitada y se ha perdido los primeros dos juegos de la temporada. Hufanga logro recuperarse d', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=OVFT.VP5KaqJje5S1YffDIp5zUi&pid=News', 'height': 420, 'width': 630}}, 'name': 'Talanoa Hufanga Logra Entrenar Sin Limitaciones', 'provider': [{'_type': 'Organization', 'image': {'thumbnail': {'contentUrl': 'https://www.bing.com/th?id=ODF.k6O3sRggnv9dZCaM2w5RLw&pid=news'}}, 'name': 'Big News Network.com'}], 'url': 'https://www.bignewsnetwork.com/news/274621218/talanoa-hufanga-logra-entrenar-sin-limitaciones'}}

# %%
print(news_json['json_object']['name'])
print(news_json['json_object']['description'])
print(news_json['json_object']['datePublished'])
print(news_json['json_object']['url'])
print(news_json['json_object']['image']['thumbnail']['contentUrl'])
print(news_json['json_object']['provider'][0]['name'])
# Out:
# StatementMeta(, 1c7e5fd2-7741-4804-9786-27e0e159a968, 50, Finished, Available, Finished)
# Talanoa Hufanga Logra Entrenar Sin Limitaciones
# El profundo Talanoa Hufanga ha estado entrenando con el resto del equipo las últimas dos semanas de manera limitada y se ha perdido los primeros dos juegos de la temporada. Hufanga logro recuperarse d
# 2024-09-21T19:56:00.0000000Z
# https://www.bignewsnetwork.com/news/274621218/talanoa-hufanga-logra-entrenar-sin-limitaciones
# https://www.bing.com/th?id=OVFT.VP5KaqJje5S1YffDIp5zUi&pid=News
# Big News Network.com
